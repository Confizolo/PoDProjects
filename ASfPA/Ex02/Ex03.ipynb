# %% [markdown]
# # Assignement 2 - Filippo Conforto

# %% [markdown]
# ## Exercise 1

# %%
x = c(15.58, 15.9, 16, 16.1, 16.2)
p1 = c(0.15,0.21,0.35, 0.15, 0.14)
p2 = c(0.14, 0.05, 0.64, 0.08, 0.09)

# %%
sum(x*p1)
sum(x*p2)
sqrt(sum((x^2)*p1) - sum(x*p1)^2)
sqrt(sum((x^2)*p2) - sum(x*p2)^2)
# Out:
# [1] 15.959
# [1] 15.9622
# [1] 0.1843339
# [1] 0.1678307

# %% [markdown]
# ## Exercise 2

# %%
sim =rexp(50,rate = 1/30)

# %%
hist(sim)
# Out:
# Plot with title “Histogram of sim”

# %%
pexp(10, rate= 1/30)
# Out:
# [1] 0.2834687

# %%
mean(sim)
# Out:
# [1] 29.43593

# %% [markdown]
# mean(sim) ??? R Manipulation

# %%
1- pexp(60, rate=1/30 )
# Out:
# [1] 0.1353353

# %% [markdown]
# ## Exercise 3

# %%
plot(dpois(0:10, 1/3))
# Out:
# plot without title

# %%
plot(ppois(0:10, 1/3))
# Out:
# plot without title

# %%
dpois(1, 1/3)
# Out:
# [1] 0.2388438

# %% [markdown]
# ## Exercise 4

# %%
1-pgeom(10,1/13)
# Out:
# [1] 0.4145881

# %% [markdown]
# ## Exercise 5

# %%
dtolc = function(x,c=6) {
    ifelse((x>1) & (x<2), return(c*(x-1)*(2-x)), return(0))  
}

# %%
x.integral = integrate(dtolc, 1, 2)

# %%
x.integral
# Out:
# 1 with absolute error < 1.1e-14

# %%
ptolc = function(x,c=6){
    ifelse((x>1) & (x<2), return(c*(-(x^3)/3+3/2*x^2-2*x)), return(0))  
}

# %%
rtolc = function(n,c=6){
    us = runif(n)
    ifelse((x>1) & (x<2), return(c*(-(x^3)/3+3/2*x^2-2*x)), return(0))  
}

# %%
qtolc = function(x,c=6){
    ifelse((x>1) & (x<2), return(c*(-(x^3)/3+3/2*x^2-2*x)), return(0))  
}
